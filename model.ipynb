# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pathlib
import glob

# %%
trainingdata = tf.keras.utils.image_dataset_from_directory(
  "C:\\Users\\19259\\Desktop\\LVL5\\ImageClassification\\DATA\\train",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(224,224),
  batch_size=32,
  color_mode="grayscale")
class_names = trainingdata.class_names
# Out:
# Found 13492 files belonging to 100 classes.
# Using 10794 files for training.

# %%
plt.figure(figsize=(10, 10))
for images, labels in trainingdata.take(1):
  for i in range(32):
    ax = plt.subplot(8, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
model=tf.keras.Sequential([tf.keras.layers.Input(shape=(224,224)),
                           tf.keras.layers.Rescaling(1./255),
                           tf.keras.layers.Flatten(),
                           tf.keras.layers.Dense(512, activation="relu"),
                           tf.keras.layers.Dropout(0.2),
                           tf.keras.layers.Dense(128, activation="relu"),
                           tf.keras.layers.Dropout(0.2),
                           tf.keras.layers.Dense(100)])

model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=["accuracy"])
model.fit(trainingdata,epochs=50)
# Out:
# Epoch 1/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 47s 138ms/step - accuracy: 0.0092 - loss: 6.9336
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 44s 129ms/step - accuracy: 0.0114 - loss: 4.6047
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 44s 131ms/step - accuracy: 0.0121 - loss: 4.6000
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 44s 131ms/step - accuracy: 0.0111 - loss: 4.6015
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 47s 139ms/step - accuracy: 0.0124 - loss: 4.5971
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 48s 143ms/step - accuracy: 0.0129 - loss: 4.5978
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 48s 142ms/step - accuracy: 0.0129 - loss: 4.5971
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 44s 129ms/step - accuracy: 0.0133 - loss: 4.5962
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 44s 129ms/step - accuracy: 0.0131 - loss: 4.5982
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 43s 129ms/step - accuracy: 0.0130 - loss: 4.5966
# Epoch 11/50
# ...
